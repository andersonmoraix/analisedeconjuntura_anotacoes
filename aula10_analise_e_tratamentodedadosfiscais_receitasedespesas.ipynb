# %% [markdown]
# <a href="https://colab.research.google.com/github/andersonmoraix/analisedeconjuntura_anotacoes/blob/main/aula10_analise_e_tratamentodedadosfiscais_receitasedespesas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas

# %%
# Instala bibliotecas
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)

# %%
# Importa bibliotecas
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# # Coleta de dados

# %%
# Códigos IBGE dos entes federativos para a análise

#procurar pela api do tesouro (api datalake ou Sinconfi), bom procurar por conta própria pois ela mudar de lugar(apiodatalake.tesouro.gov.br)
codigos_entes = pd.DataFrame(
    requests.get("https://apidatalake.tesouro.gov.br/ords/siconfi/tt/entes")
    .json()["items"]
    ).query("esfera in ['U', 'E']")
codigos_entes
# Out:
#       cod_ibge                 ente capital regiao    uf esfera  exercicio  \
# 4180        17            Tocantins     0       NO    BR      E       2025
# 5036         1                União     0       BR  None      U       2025
# 5037        11             Rondônia     0       NO    BR      E       2025
# 5038        12                 Acre     0       NO    BR      E       2025
# 5039        13             Amazonas     0       NO    BR      E       2025
# 5040        14              Roraima     0       NO    BR      E       2025
# 5041        15                 Pará     0       NO    BR      E       2025
# 5042        16                Amapá     0       NO    BR      E       2025
# 5043        21             Maranhão     0       NE    BR      E       2025
# 5044        22                Piauí     0       NE    BR      E       2025
# 5045        23                Ceará     0       NE    BR      E       2025
# 5046        24  Rio Grande do Norte     0       NE    BR      E       2025
# 5047        25              Paraíba     0       NE    BR      E       2025
# 5048        26           Pernambuco     0       NE    BR      E       2025
# 5049        27              Alagoas     0       NE    BR      E       2025
# 5050        28              Sergipe     0       NE    BR      E       2025
# 5051        29                Bahia     0       NE    BR      E       2025
# 5052        31         Minas Gerais     0       SE    BR      E       2025
# 5053        32       Espírito Santo     0       SE    BR      E       2025
# 5054        33       Rio de Janeiro     0       SE    BR      E       2025
# 5055        35            São Paulo     0       SE    BR      E       2025
# 5056        41               Paraná     0       SU    BR      E       2025
# 5057        42       Santa Catarina     0       SU    BR      E       2025
# 5058        43    Rio Grande do Sul     0       SU    BR      E       2025
# 5059        50   Mato Grosso do Sul     0       CO    BR      E       2025
# 5060        51          Mato Grosso     0       CO    BR      E       2025
# 5061        52                Goiás     0       CO    BR      E       2025
#
#       populacao            cnpj
# 4180    1584306  01786029000103
# 5036    8569324  00394411000109
# 5037    1616379  00394585000171
# 5038     829780  63606479000124
# 5039    3952262  04312369000190
# 5040     634805  84012012000126
# 5041    8442962  05054861000176
# 5042     774268  00394577000125
# 5043    6800605  06354468000160
# 5044    3270174  06553481000149
# 5045    8936431  07954480000179
# 5046    3303953  08241739000105
# 5047    4030961  08761124000100
# 5048    9051113  10571982000125
# 5049    3125254  12200176000176
# 5050    2211868  13128798000101
# 5051   14659023  13937032000160
# 5052   20732660  18715615000160
# 5053    3975100  27080530000143
# 5054   16615526  42498600000171
# 5055   46024937  46379400000150
# 5056   11835379  76416940000128
# 5057    7762154  82951229000176
# 5058   11088065  87934675000196
# 5059    2833742  15412257000128
# 5060    3784239  03507415000144
# 5061    6950976  01409580000138

# %%
# Coleta de dados do SICONFI
# DCA - Declaração de contas anuais - IC - Demonstrativo de Receitas Orçamentárias
dados_brutos_q1 = list(
    map(
        lambda x: pd.DataFrame(
            requests.get(
                "https://apidatalake.tesouro.gov.br/ords/siconfi/tt/dca?an_exercicio=2021&no_anexo=DCA-Anexo%20I-C&id_ente=" + x #aonde foi aplicado o filtro
                )
            .json()["items"]
            ),
        codigos_entes.cod_ibge.astype(str).tolist()
        )
    )
dados_brutos_q1

# Coleta de dados do SICONFI
# DCA - Declaração de contas anuais - IE - Demonstrativo de Despesas Orçamentárias por Função
dados_brutos_q2 = list(
    map(
        lambda x: pd.DataFrame(
            requests.get(
                "https://apidatalake.tesouro.gov.br/ords/siconfi/tt/dca?an_exercicio=2021&no_anexo=DCA-Anexo%20I-E&id_ente=" + x
            )
            .json()["items"]
            ),
        codigos_entes.cod_ibge.astype(str).tolist()
        )
    )
dados_brutos_q2
# Out:
# [     exercicio                     instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#  1         2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#  2         2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#  3         2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#  4         2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#  ..         ...                             ...       ...  ..            ...
#  544       2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#  545       2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#  546       2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#  547       2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#  548       2021  Governo do Estado do Tocantins        17  TO  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  544  Total Geral da Despesa por Função
#  545  Total Geral da Despesa por Função
#  546  Total Geral da Despesa por Função
#  547  Total Geral da Despesa por Função
#  548  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  544  Inscrição de Restos a Pagar Processados  TotalDespesas
#  545  Inscrição de Restos a Pagar Processados  TotalDespesas
#  546  Inscrição de Restos a Pagar Processados  TotalDespesas
#  547  Inscrição de Restos a Pagar Processados  TotalDespesas
#  548  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  1.067031e+10    1590248
#  1                      01 - Legislativa  4.038364e+08    1590248
#  2             01.031 - Ação Legislativa  2.643841e+08    1590248
#  3             01.032 - Controle Externo  1.459574e+06    1590248
#  4          01.122 - Administração Geral  1.112229e+08    1590248
#  ..                                  ...           ...        ...
#  544       27.812 - Desporto Comunitário  7.487000e+01    1590248
#  545             28 - Encargos Especiais  7.540570e+06    1590248
#  546  28.843 - Serviço da Dívida Interna  1.860611e+05    1590248
#  547      28.845 - Outras Transferências  7.354509e+06    1590248
#  548         Despesas Intraorçamentárias  4.350297e+07    1590248
#
#  [549 rows x 11 columns],
#       exercicio      instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo Federal         1  BR  DCA-Anexo I-E
#  1         2021  Governo Federal         1  BR  DCA-Anexo I-E
#  2         2021  Governo Federal         1  BR  DCA-Anexo I-E
#  3         2021  Governo Federal         1  BR  DCA-Anexo I-E
#  4         2021  Governo Federal         1  BR  DCA-Anexo I-E
#  ..         ...              ...       ...  ..            ...
#  807       2021  Governo Federal         1  BR  DCA-Anexo I-E
#  808       2021  Governo Federal         1  BR  DCA-Anexo I-E
#  809       2021  Governo Federal         1  BR  DCA-Anexo I-E
#  810       2021  Governo Federal         1  BR  DCA-Anexo I-E
#  811       2021  Governo Federal         1  BR  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  807  Total Geral da Despesa por Função
#  808  Total Geral da Despesa por Função
#  809  Total Geral da Despesa por Função
#  810  Total Geral da Despesa por Função
#  811  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  807  Inscrição de Restos a Pagar Processados  TotalDespesas
#  808  Inscrição de Restos a Pagar Processados  TotalDespesas
#  809  Inscrição de Restos a Pagar Processados  TotalDespesas
#  810  Inscrição de Restos a Pagar Processados  TotalDespesas
#  811  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  4.010963e+12    8569324
#  1                      01 - Legislativa  6.689866e+09    8569324
#  2             01.031 - Ação Legislativa  9.474554e+08    8569324
#  3             01.032 - Controle Externo  2.007512e+08    8569324
#  4          01.122 - Administração Geral  4.764501e+09    8569324
#  ..                                  ...           ...        ...
#  807  28.843 - Serviço da Dívida Interna  2.079629e+06    8569324
#  808      28.845 - Outras Transferências  3.164796e+08    8569324
#  809  28.846 - Outros Encargos Especiais  1.762518e+08    8569324
#  810            FU28 - Demais Subfunções  1.707406e+08    8569324
#  811         Despesas Intraorçamentárias  1.355933e+08    8569324
#
#  [812 rows x 11 columns],
#       exercicio                    instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#  1         2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#  2         2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#  3         2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#  4         2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#  ..         ...                            ...       ...  ..            ...
#  512       2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#  513       2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#  514       2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#  515       2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#  516       2021  Governo do Estado de Rondônia        11  RO  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  512  Total Geral da Despesa por Função
#  513  Total Geral da Despesa por Função
#  514  Total Geral da Despesa por Função
#  515  Total Geral da Despesa por Função
#  516  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  512  Inscrição de Restos a Pagar Processados  TotalDespesas
#  513  Inscrição de Restos a Pagar Processados  TotalDespesas
#  514  Inscrição de Restos a Pagar Processados  TotalDespesas
#  515  Inscrição de Restos a Pagar Processados  TotalDespesas
#  516  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  9.629166e+09    1796460
#  1                      01 - Legislativa  3.730964e+08    1796460
#  2             01.031 - Ação Legislativa  1.099683e+08    1796460
#  3             01.032 - Controle Externo  2.433724e+05    1796460
#  4          01.122 - Administração Geral  2.298483e+08    1796460
#  ..                                  ...           ...        ...
#  512       27.812 - Desporto Comunitário  7.324999e+05    1796460
#  513        27.122 - Administração Geral  4.260918e+04    1796460
#  514             28 - Encargos Especiais  3.776070e+03    1796460
#  515  28.846 - Outros Encargos Especiais  3.776070e+03    1796460
#  516         Despesas Intraorçamentárias  5.862588e+05    1796460
#
#  [517 rows x 11 columns],
#       exercicio                instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#  1         2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#  2         2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#  3         2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#  4         2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#  ..         ...                        ...       ...  ..            ...
#  537       2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#  538       2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#  539       2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#  540       2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#  541       2021  Governo do Estado do Acre        12  AC  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  537  Total Geral da Despesa por Função
#  538  Total Geral da Despesa por Função
#  539  Total Geral da Despesa por Função
#  540  Total Geral da Despesa por Função
#  541  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  537  Inscrição de Restos a Pagar Processados  TotalDespesas
#  538  Inscrição de Restos a Pagar Processados  TotalDespesas
#  539  Inscrição de Restos a Pagar Processados  TotalDespesas
#  540  Inscrição de Restos a Pagar Processados  TotalDespesas
#  541  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  7.452807e+09     894470
#  1                      01 - Legislativa  2.660607e+08     894470
#  2             01.031 - Ação Legislativa  1.773309e+08     894470
#  3             01.032 - Controle Externo  8.872987e+07     894470
#  4                       02 - Judiciária  2.578252e+08     894470
#  ..                                  ...           ...        ...
#  537       27.812 - Desporto Comunitário  3.200000e+05     894470
#  538             28 - Encargos Especiais  2.136400e+03     894470
#  539  28.843 - Serviço da Dívida Interna  1.242950e+03     894470
#  540  28.846 - Outros Encargos Especiais  8.934500e+02     894470
#  541         Despesas Intraorçamentárias  4.774729e+05     894470
#
#  [542 rows x 11 columns],
#       exercicio                    instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#  1         2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#  2         2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#  3         2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#  4         2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#  ..         ...                            ...       ...  ..            ...
#  559       2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#  560       2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#  561       2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#  562       2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#  563       2021  Governo do Estado do Amazonas        13  AM  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  559  Total Geral da Despesa por Função
#  560  Total Geral da Despesa por Função
#  561  Total Geral da Despesa por Função
#  562  Total Geral da Despesa por Função
#  563  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  559  Inscrição de Restos a Pagar Processados  TotalDespesas
#  560  Inscrição de Restos a Pagar Processados  TotalDespesas
#  561  Inscrição de Restos a Pagar Processados  TotalDespesas
#  562  Inscrição de Restos a Pagar Processados  TotalDespesas
#  563  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  2.383175e+10    4207714
#  1                      01 - Legislativa  8.585717e+08    4207714
#  2             01.031 - Ação Legislativa  3.287560e+08    4207714
#  3             01.032 - Controle Externo  1.818384e+06    4207714
#  4          01.122 - Administração Geral  2.666542e+08    4207714
#  ..                                  ...           ...        ...
#  559        26.122 - Administração Geral  3.955184e+04    4207714
#  560             28 - Encargos Especiais  1.218333e+06    4207714
#  561  28.846 - Outros Encargos Especiais  1.206221e+06    4207714
#  562            FU28 - Demais Subfunções  1.211200e+04    4207714
#  563         Despesas Intraorçamentárias  1.231882e+07    4207714
#
#  [564 rows x 11 columns],
#       exercicio                   instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#  1         2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#  2         2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#  3         2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#  4         2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#  ..         ...                           ...       ...  ..            ...
#  464       2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#  465       2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#  466       2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#  467       2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#  468       2021  Governo do Estado de Roraima        14  RR  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  464  Total Geral da Despesa por Função
#  465  Total Geral da Despesa por Função
#  466  Total Geral da Despesa por Função
#  467  Total Geral da Despesa por Função
#  468  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  464  Inscrição de Restos a Pagar Processados  TotalDespesas
#  465  Inscrição de Restos a Pagar Processados  TotalDespesas
#  466  Inscrição de Restos a Pagar Processados  TotalDespesas
#  467  Inscrição de Restos a Pagar Processados  TotalDespesas
#  468  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  5.008994e+09     631181
#  1                      01 - Legislativa  3.829591e+08     631181
#  2             01.031 - Ação Legislativa  2.862162e+08     631181
#  3             01.032 - Controle Externo  9.674296e+07     631181
#  4                       02 - Judiciária  2.802800e+08     631181
#  ..                                  ...           ...        ...
#  464      26.782 - Transporte Rodoviário  1.298341e+05     631181
#  465               27 - Desporto e Lazer  1.954263e+05     631181
#  466     27.811 - Desporto de Rendimento  6.682500e+04     631181
#  467       27.812 - Desporto Comunitário  1.286013e+05     631181
#  468         Despesas Intraorçamentárias  5.821304e+06     631181
#
#  [469 rows x 11 columns],
#       exercicio                instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#  1         2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#  2         2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#  3         2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#  4         2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#  ..         ...                        ...       ...  ..            ...
#  603       2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#  604       2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#  605       2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#  606       2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#  607       2021  Governo do Estado do Pará        15  PA  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  603  Total Geral da Despesa por Função
#  604  Total Geral da Despesa por Função
#  605  Total Geral da Despesa por Função
#  606  Total Geral da Despesa por Função
#  607  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  603  Inscrição de Restos a Pagar Processados  TotalDespesas
#  604  Inscrição de Restos a Pagar Processados  TotalDespesas
#  605  Inscrição de Restos a Pagar Processados  TotalDespesas
#  606  Inscrição de Restos a Pagar Processados  TotalDespesas
#  607  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  3.339288e+10    8690745
#  1                      01 - Legislativa  9.246236e+08    8690745
#  2             01.031 - Ação Legislativa  2.816098e+07    8690745
#  3             01.032 - Controle Externo  1.964708e+08    8690745
#  4          01.122 - Administração Geral  5.410423e+08    8690745
#  ..                                  ...           ...        ...
#  603        27.122 - Administração Geral  1.559646e+04    8690745
#  604             28 - Encargos Especiais  1.594087e+08    8690745
#  605      28.845 - Outras Transferências  1.693390e+07    8690745
#  606  28.846 - Outros Encargos Especiais  1.424748e+08    8690745
#  607         Despesas Intraorçamentárias  6.698900e+07    8690745
#
#  [608 rows x 11 columns],
#       exercicio                 instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#  1         2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#  2         2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#  3         2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#  4         2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#  ..         ...                         ...       ...  ..            ...
#  508       2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#  509       2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#  510       2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#  511       2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#  512       2021  Governo do Estado do Amapá        16  AP  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  508  Total Geral da Despesa por Função
#  509  Total Geral da Despesa por Função
#  510  Total Geral da Despesa por Função
#  511  Total Geral da Despesa por Função
#  512  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  508  Inscrição de Restos a Pagar Processados  TotalDespesas
#  509  Inscrição de Restos a Pagar Processados  TotalDespesas
#  510  Inscrição de Restos a Pagar Processados  TotalDespesas
#  511  Inscrição de Restos a Pagar Processados  TotalDespesas
#  512  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  5.749154e+09     861773
#  1                      01 - Legislativa  2.646447e+08     861773
#  2             01.031 - Ação Legislativa  3.112083e+07     861773
#  3             01.032 - Controle Externo  5.991608e+07     861773
#  4          01.122 - Administração Geral  1.706867e+08     861773
#  ..                                  ...           ...        ...
#  508               27 - Desporto e Lazer  2.515136e+06     861773
#  509     27.811 - Desporto de Rendimento  1.034000e+06     861773
#  510                      27.813 - Lazer  1.328456e+06     861773
#  511        27.122 - Administração Geral  1.526800e+05     861773
#  512         Despesas Intraorçamentárias  9.479903e+07     861773
#
#  [513 rows x 11 columns],
#       exercicio                    instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#  1         2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#  2         2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#  3         2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#  4         2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#  ..         ...                            ...       ...  ..            ...
#  589       2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#  590       2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#  591       2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#  592       2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#  593       2021  Governo do Estado do Maranhão        21  MA  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  589  Total Geral da Despesa por Função
#  590  Total Geral da Despesa por Função
#  591  Total Geral da Despesa por Função
#  592  Total Geral da Despesa por Função
#  593  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  589  Inscrição de Restos a Pagar Processados  TotalDespesas
#  590  Inscrição de Restos a Pagar Processados  TotalDespesas
#  591  Inscrição de Restos a Pagar Processados  TotalDespesas
#  592  Inscrição de Restos a Pagar Processados  TotalDespesas
#  593  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  2.021671e+10    7114598
#  1                      01 - Legislativa  5.971098e+08    7114598
#  2             01.031 - Ação Legislativa  3.624479e+08    7114598
#  3             01.032 - Controle Externo  1.614487e+08    7114598
#  4          01.122 - Administração Geral  1.367034e+06    7114598
#  ..                                  ...           ...        ...
#  589        27.122 - Administração Geral  1.879863e+04    7114598
#  590            FU27 - Demais Subfunções  1.695159e+06    7114598
#  591             28 - Encargos Especiais  1.836814e+04    7114598
#  592  28.846 - Outros Encargos Especiais  1.836814e+04    7114598
#  593         Despesas Intraorçamentárias  1.438433e+08    7114598
#
#  [594 rows x 11 columns],
#       exercicio                 instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#  1         2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#  2         2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#  3         2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#  4         2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#  ..         ...                         ...       ...  ..            ...
#  487       2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#  488       2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#  489       2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#  490       2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#  491       2021  Governo do Estado do Piauí        22  PI  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  487  Total Geral da Despesa por Função
#  488  Total Geral da Despesa por Função
#  489  Total Geral da Despesa por Função
#  490  Total Geral da Despesa por Função
#  491  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  487  Inscrição de Restos a Pagar Processados  TotalDespesas
#  488  Inscrição de Restos a Pagar Processados  TotalDespesas
#  489  Inscrição de Restos a Pagar Processados  TotalDespesas
#  490  Inscrição de Restos a Pagar Processados  TotalDespesas
#  491  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  1.289963e+10    3281480
#  1                      01 - Legislativa  5.313994e+08    3281480
#  2             01.031 - Ação Legislativa  3.947599e+08    3281480
#  3             01.032 - Controle Externo  1.366395e+08    3281480
#  4                       02 - Judiciária  6.174099e+08    3281480
#  ..                                  ...           ...        ...
#  487       27.812 - Desporto Comunitário  3.110558e+05    3281480
#  488        27.122 - Administração Geral  1.570500e+03    3281480
#  489             28 - Encargos Especiais  4.344021e+04    3281480
#  490  28.846 - Outros Encargos Especiais  4.344021e+04    3281480
#  491         Despesas Intraorçamentárias  1.458681e+08    3281480
#
#  [492 rows x 11 columns],
#       exercicio                 instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#  1         2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#  2         2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#  3         2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#  4         2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#  ..         ...                         ...       ...  ..            ...
#  565       2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#  566       2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#  567       2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#  568       2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#  569       2021  Governo do Estado do Ceará        23  CE  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  565  Total Geral da Despesa por Função
#  566  Total Geral da Despesa por Função
#  567  Total Geral da Despesa por Função
#  568  Total Geral da Despesa por Função
#  569  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  565  Inscrição de Restos a Pagar Processados  TotalDespesas
#  566  Inscrição de Restos a Pagar Processados  TotalDespesas
#  567  Inscrição de Restos a Pagar Processados  TotalDespesas
#  568  Inscrição de Restos a Pagar Processados  TotalDespesas
#  569  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  3.116545e+10    9187103
#  1                      01 - Legislativa  7.266545e+08    9187103
#  2             01.031 - Ação Legislativa  6.343792e+07    9187103
#  3             01.032 - Controle Externo  1.533163e+08    9187103
#  4          01.122 - Administração Geral  5.013422e+08    9187103
#  ..                                  ...           ...        ...
#  565        26.122 - Administração Geral  1.322451e+05    9187103
#  566             28 - Encargos Especiais  7.646632e+07    9187103
#  567      28.845 - Outras Transferências  7.646575e+07    9187103
#  568  28.846 - Outros Encargos Especiais  5.716700e+02    9187103
#  569         Despesas Intraorçamentárias  3.462924e+07    9187103
#
#  [570 rows x 11 columns],
#       exercicio                               instituicao  cod_ibge  uf  \
#  0         2021  Governo do Estado do Rio Grande do Norte        24  RN
#  1         2021  Governo do Estado do Rio Grande do Norte        24  RN
#  2         2021  Governo do Estado do Rio Grande do Norte        24  RN
#  3         2021  Governo do Estado do Rio Grande do Norte        24  RN
#  4         2021  Governo do Estado do Rio Grande do Norte        24  RN
#  ..         ...                                       ...       ...  ..
#  484       2021  Governo do Estado do Rio Grande do Norte        24  RN
#  485       2021  Governo do Estado do Rio Grande do Norte        24  RN
#  486       2021  Governo do Estado do Rio Grande do Norte        24  RN
#  487       2021  Governo do Estado do Rio Grande do Norte        24  RN
#  488       2021  Governo do Estado do Rio Grande do Norte        24  RN
#
#               anexo                             rotulo  \
#  0    DCA-Anexo I-E  Total Geral da Despesa por Função
#  1    DCA-Anexo I-E  Total Geral da Despesa por Função
#  2    DCA-Anexo I-E  Total Geral da Despesa por Função
#  3    DCA-Anexo I-E  Total Geral da Despesa por Função
#  4    DCA-Anexo I-E  Total Geral da Despesa por Função
#  ..             ...                                ...
#  484  DCA-Anexo I-E  Total Geral da Despesa por Função
#  485  DCA-Anexo I-E  Total Geral da Despesa por Função
#  486  DCA-Anexo I-E  Total Geral da Despesa por Função
#  487  DCA-Anexo I-E  Total Geral da Despesa por Função
#  488  DCA-Anexo I-E  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  484  Inscrição de Restos a Pagar Processados  TotalDespesas
#  485  Inscrição de Restos a Pagar Processados  TotalDespesas
#  486  Inscrição de Restos a Pagar Processados  TotalDespesas
#  487  Inscrição de Restos a Pagar Processados  TotalDespesas
#  488  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  1.310282e+10    3534165
#  1                      01 - Legislativa  4.499405e+08    3534165
#  2             01.031 - Ação Legislativa  2.508308e+07    3534165
#  3             01.032 - Controle Externo  6.332726e+06    3534165
#  4          01.122 - Administração Geral  4.167109e+08    3534165
#  ..                                  ...           ...        ...
#  484        26.122 - Administração Geral  6.024518e+06    3534165
#  485            FU26 - Demais Subfunções  1.459520e+06    3534165
#  486             28 - Encargos Especiais  6.530000e+05    3534165
#  487      28.845 - Outras Transferências  6.530000e+05    3534165
#  488         Despesas Intraorçamentárias  1.248888e+08    3534165
#
#  [489 rows x 11 columns],
#       exercicio                   instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#  1         2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#  2         2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#  3         2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#  4         2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#  ..         ...                           ...       ...  ..            ...
#  589       2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#  590       2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#  591       2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#  592       2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#  593       2021  Governo do Estado da Paraíba        25  PB  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  589  Total Geral da Despesa por Função
#  590  Total Geral da Despesa por Função
#  591  Total Geral da Despesa por Função
#  592  Total Geral da Despesa por Função
#  593  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  589  Inscrição de Restos a Pagar Processados  TotalDespesas
#  590  Inscrição de Restos a Pagar Processados  TotalDespesas
#  591  Inscrição de Restos a Pagar Processados  TotalDespesas
#  592  Inscrição de Restos a Pagar Processados  TotalDespesas
#  593  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  1.236316e+10    4039277
#  1                      01 - Legislativa  4.063070e+08    4039277
#  2             01.031 - Ação Legislativa  4.288322e+07    4039277
#  3             01.032 - Controle Externo  1.299959e+06    4039277
#  4          01.122 - Administração Geral  3.618483e+08    4039277
#  ..                                  ...           ...        ...
#  589       27.812 - Desporto Comunitário  1.500000e+04    4039277
#  590        27.122 - Administração Geral  2.461106e+04    4039277
#  591             28 - Encargos Especiais  2.788899e+06    4039277
#  592  28.846 - Outros Encargos Especiais  2.788899e+06    4039277
#  593         Despesas Intraorçamentárias  8.641969e+06    4039277
#
#  [594 rows x 11 columns],
#       exercicio                      instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#  1         2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#  2         2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#  3         2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#  4         2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#  ..         ...                              ...       ...  ..            ...
#  535       2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#  536       2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#  537       2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#  538       2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#  539       2021  Governo do Estado de Pernambuco        26  PE  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  535  Total Geral da Despesa por Função
#  536  Total Geral da Despesa por Função
#  537  Total Geral da Despesa por Função
#  538  Total Geral da Despesa por Função
#  539  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  535  Inscrição de Restos a Pagar Processados  TotalDespesas
#  536  Inscrição de Restos a Pagar Processados  TotalDespesas
#  537  Inscrição de Restos a Pagar Processados  TotalDespesas
#  538  Inscrição de Restos a Pagar Processados  TotalDespesas
#  539  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  3.791079e+10    9616621
#  1                      01 - Legislativa  8.514237e+08    9616621
#  2             01.031 - Ação Legislativa  6.096308e+07    9616621
#  3             01.032 - Controle Externo  2.483478e+08    9616621
#  4          01.122 - Administração Geral  4.330651e+08    9616621
#  ..                                  ...           ...        ...
#  535            FU27 - Demais Subfunções  1.866179e+05    9616621
#  536             28 - Encargos Especiais  2.548502e+08    9616621
#  537      28.845 - Outras Transferências  2.285990e+08    9616621
#  538  28.846 - Outros Encargos Especiais  2.625120e+07    9616621
#  539         Despesas Intraorçamentárias  3.039951e+07    9616621
#
#  [540 rows x 11 columns],
#       exercicio                   instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#  1         2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#  2         2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#  3         2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#  4         2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#  ..         ...                           ...       ...  ..            ...
#  526       2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#  527       2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#  528       2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#  529       2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#  530       2021  Governo do Estado de Alagoas        27  AL  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  526  Total Geral da Despesa por Função
#  527  Total Geral da Despesa por Função
#  528  Total Geral da Despesa por Função
#  529  Total Geral da Despesa por Função
#  530  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  526  Inscrição de Restos a Pagar Processados  TotalDespesas
#  527  Inscrição de Restos a Pagar Processados  TotalDespesas
#  528  Inscrição de Restos a Pagar Processados  TotalDespesas
#  529  Inscrição de Restos a Pagar Processados  TotalDespesas
#  530  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  1.399667e+10    3351543
#  1                      01 - Legislativa  4.033466e+08    3351543
#  2             01.031 - Ação Legislativa  1.126724e+06    3351543
#  3             01.032 - Controle Externo  8.992450e+07    3351543
#  4          01.122 - Administração Geral  3.122954e+08    3351543
#  ..                                  ...           ...        ...
#  526        27.122 - Administração Geral  4.215607e+04    3351543
#  527             28 - Encargos Especiais  4.763801e+07    3351543
#  528  28.843 - Serviço da Dívida Interna  4.020263e+04    3351543
#  529  28.846 - Outros Encargos Especiais  4.759780e+07    3351543
#  530         Despesas Intraorçamentárias  2.661946e+07    3351543
#
#  [531 rows x 11 columns],
#       exercicio                   instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#  1         2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#  2         2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#  3         2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#  4         2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#  ..         ...                           ...       ...  ..            ...
#  505       2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#  506       2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#  507       2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#  508       2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#  509       2021  Governo do Estado de Sergipe        28  SE  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  505  Total Geral da Despesa por Função
#  506  Total Geral da Despesa por Função
#  507  Total Geral da Despesa por Função
#  508  Total Geral da Despesa por Função
#  509  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  505  Inscrição de Restos a Pagar Processados  TotalDespesas
# ...
#  485             28 - Encargos Especiais  1.981669e+05   11516840
#  486  28.846 - Outros Encargos Especiais  1.981669e+05   11516840
#  487         Despesas Intraorçamentárias  2.386240e+03   11516840
#
#  [488 rows x 11 columns],
#       exercicio                          instituicao  cod_ibge  uf  \
#  0         2021  Governo do Estado de Santa Catarina        42  SC
#  1         2021  Governo do Estado de Santa Catarina        42  SC
#  2         2021  Governo do Estado de Santa Catarina        42  SC
#  3         2021  Governo do Estado de Santa Catarina        42  SC
#  4         2021  Governo do Estado de Santa Catarina        42  SC
#  ..         ...                                  ...       ...  ..
#  508       2021  Governo do Estado de Santa Catarina        42  SC
#  509       2021  Governo do Estado de Santa Catarina        42  SC
#  510       2021  Governo do Estado de Santa Catarina        42  SC
#  511       2021  Governo do Estado de Santa Catarina        42  SC
#  512       2021  Governo do Estado de Santa Catarina        42  SC
#
#               anexo                             rotulo  \
#  0    DCA-Anexo I-E  Total Geral da Despesa por Função
#  1    DCA-Anexo I-E  Total Geral da Despesa por Função
#  2    DCA-Anexo I-E  Total Geral da Despesa por Função
#  3    DCA-Anexo I-E  Total Geral da Despesa por Função
#  4    DCA-Anexo I-E  Total Geral da Despesa por Função
#  ..             ...                                ...
#  508  DCA-Anexo I-E  Total Geral da Despesa por Função
#  509  DCA-Anexo I-E  Total Geral da Despesa por Função
#  510  DCA-Anexo I-E  Total Geral da Despesa por Função
#  511  DCA-Anexo I-E  Total Geral da Despesa por Função
#  512  DCA-Anexo I-E  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  508  Inscrição de Restos a Pagar Processados  TotalDespesas
#  509  Inscrição de Restos a Pagar Processados  TotalDespesas
#  510  Inscrição de Restos a Pagar Processados  TotalDespesas
#  511  Inscrição de Restos a Pagar Processados  TotalDespesas
#  512  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  3.201637e+10    7252502
#  1                      01 - Legislativa  5.970868e+08    7252502
#  2             01.031 - Ação Legislativa  6.023368e+07    7252502
#  3          01.122 - Administração Geral  5.128489e+08    7252502
#  4              FU01 - Demais Subfunções  2.400429e+07    7252502
#  ..                                  ...           ...        ...
#  508               27 - Desporto e Lazer  8.851044e+04    7252502
#  509       27.812 - Desporto Comunitário  8.851044e+04    7252502
#  510             28 - Encargos Especiais  3.953245e+07    7252502
#  511  28.846 - Outros Encargos Especiais  3.953245e+07    7252502
#  512         Despesas Intraorçamentárias  2.348650e+07    7252502
#
#  [513 rows x 11 columns],
#       exercicio                             instituicao  cod_ibge  uf  \
#  0         2021  Governo do Estado do Rio Grande do Sul        43  RS
#  1         2021  Governo do Estado do Rio Grande do Sul        43  RS
#  2         2021  Governo do Estado do Rio Grande do Sul        43  RS
#  3         2021  Governo do Estado do Rio Grande do Sul        43  RS
#  4         2021  Governo do Estado do Rio Grande do Sul        43  RS
#  ..         ...                                     ...       ...  ..
#  607       2021  Governo do Estado do Rio Grande do Sul        43  RS
#  608       2021  Governo do Estado do Rio Grande do Sul        43  RS
#  609       2021  Governo do Estado do Rio Grande do Sul        43  RS
#  610       2021  Governo do Estado do Rio Grande do Sul        43  RS
#  611       2021  Governo do Estado do Rio Grande do Sul        43  RS
#
#               anexo                             rotulo  \
#  0    DCA-Anexo I-E  Total Geral da Despesa por Função
#  1    DCA-Anexo I-E  Total Geral da Despesa por Função
#  2    DCA-Anexo I-E  Total Geral da Despesa por Função
#  3    DCA-Anexo I-E  Total Geral da Despesa por Função
#  4    DCA-Anexo I-E  Total Geral da Despesa por Função
#  ..             ...                                ...
#  607  DCA-Anexo I-E  Total Geral da Despesa por Função
#  608  DCA-Anexo I-E  Total Geral da Despesa por Função
#  609  DCA-Anexo I-E  Total Geral da Despesa por Função
#  610  DCA-Anexo I-E  Total Geral da Despesa por Função
#  611  DCA-Anexo I-E  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  607  Inscrição de Restos a Pagar Processados  TotalDespesas
#  608  Inscrição de Restos a Pagar Processados  TotalDespesas
#  609  Inscrição de Restos a Pagar Processados  TotalDespesas
#  610  Inscrição de Restos a Pagar Processados  TotalDespesas
#  611  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  5.463859e+10   11422973
#  1                      01 - Legislativa  6.155867e+08   11422973
#  2             01.031 - Ação Legislativa  3.146885e+08   11422973
#  3             01.032 - Controle Externo  2.916676e+08   11422973
#  4              FU01 - Demais Subfunções  9.230590e+06   11422973
#  ..                                  ...           ...        ...
#  607             28 - Encargos Especiais  3.494396e+09   11422973
#  608  28.843 - Serviço da Dívida Interna  3.421293e+09   11422973
#  609  28.846 - Outros Encargos Especiais  7.194190e+07   11422973
#  610            FU28 - Demais Subfunções  1.161151e+06   11422973
#  611         Despesas Intraorçamentárias  9.533192e+07   11422973
#
#  [612 rows x 11 columns],
#       exercicio                              instituicao  cod_ibge  uf  \
#  0         2021  Governo do Estado do Mato Grosso do Sul        50  MS
#  1         2021  Governo do Estado do Mato Grosso do Sul        50  MS
#  2         2021  Governo do Estado do Mato Grosso do Sul        50  MS
#  3         2021  Governo do Estado do Mato Grosso do Sul        50  MS
#  4         2021  Governo do Estado do Mato Grosso do Sul        50  MS
#  ..         ...                                      ...       ...  ..
#  454       2021  Governo do Estado do Mato Grosso do Sul        50  MS
#  455       2021  Governo do Estado do Mato Grosso do Sul        50  MS
#  456       2021  Governo do Estado do Mato Grosso do Sul        50  MS
#  457       2021  Governo do Estado do Mato Grosso do Sul        50  MS
#  458       2021  Governo do Estado do Mato Grosso do Sul        50  MS
#
#               anexo                             rotulo  \
#  0    DCA-Anexo I-E  Total Geral da Despesa por Função
#  1    DCA-Anexo I-E  Total Geral da Despesa por Função
#  2    DCA-Anexo I-E  Total Geral da Despesa por Função
#  3    DCA-Anexo I-E  Total Geral da Despesa por Função
#  4    DCA-Anexo I-E  Total Geral da Despesa por Função
#  ..             ...                                ...
#  454  DCA-Anexo I-E  Total Geral da Despesa por Função
#  455  DCA-Anexo I-E  Total Geral da Despesa por Função
#  456  DCA-Anexo I-E  Total Geral da Despesa por Função
#  457  DCA-Anexo I-E  Total Geral da Despesa por Função
#  458  DCA-Anexo I-E  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  454  Inscrição de Restos a Pagar Processados  TotalDespesas
#  455  Inscrição de Restos a Pagar Processados  TotalDespesas
#  456  Inscrição de Restos a Pagar Processados  TotalDespesas
#  457  Inscrição de Restos a Pagar Processados  TotalDespesas
#  458  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  1.645278e+10    2809394
#  1                      01 - Legislativa  4.147046e+08    2809394
#  2             01.031 - Ação Legislativa  2.152631e+08    2809394
#  3             01.032 - Controle Externo  1.979245e+08    2809394
#  4              FU01 - Demais Subfunções  1.517014e+06    2809394
#  ..                                  ...           ...        ...
#  454       27.812 - Desporto Comunitário  5.385867e+04    2809394
#  455        27.122 - Administração Geral  1.872000e+03    2809394
#  456             28 - Encargos Especiais  2.750000e+06    2809394
#  457      28.845 - Outras Transferências  2.750000e+06    2809394
#  458         Despesas Intraorçamentárias  1.633458e+07    2809394
#
#  [459 rows x 11 columns],
#       exercicio                       instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#  1         2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#  2         2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#  3         2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#  4         2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#  ..         ...                               ...       ...  ..            ...
#  534       2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#  535       2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#  536       2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#  537       2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#  538       2021  Governo do Estado do Mato Grosso        51  MT  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  534  Total Geral da Despesa por Função
#  535  Total Geral da Despesa por Função
#  536  Total Geral da Despesa por Função
#  537  Total Geral da Despesa por Função
#  538  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  534  Inscrição de Restos a Pagar Processados  TotalDespesas
#  535  Inscrição de Restos a Pagar Processados  TotalDespesas
#  536  Inscrição de Restos a Pagar Processados  TotalDespesas
#  537  Inscrição de Restos a Pagar Processados  TotalDespesas
#  538  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  2.418696e+10    3526220
#  1                      01 - Legislativa  8.273377e+08    3526220
#  2             01.031 - Ação Legislativa  2.820355e+07    3526220
#  3             01.032 - Controle Externo  5.300655e+07    3526220
#  4          01.122 - Administração Geral  6.402377e+08    3526220
#  ..                                  ...           ...        ...
#  534     27.811 - Desporto de Rendimento  2.259486e+05    3526220
#  535       27.812 - Desporto Comunitário  2.205548e+06    3526220
#  536             28 - Encargos Especiais  2.748742e+07    3526220
#  537  28.846 - Outros Encargos Especiais  2.748742e+07    3526220
#  538         Despesas Intraorçamentárias  9.177267e+05    3526220
#
#  [539 rows x 11 columns],
#       exercicio                 instituicao  cod_ibge  uf          anexo  \
#  0         2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#  1         2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#  2         2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#  3         2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#  4         2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#  ..         ...                         ...       ...  ..            ...
#  457       2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#  458       2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#  459       2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#  460       2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#  461       2021  Governo do Estado de Goiás        52  GO  DCA-Anexo I-E
#
#                                  rotulo  \
#  0    Total Geral da Despesa por Função
#  1    Total Geral da Despesa por Função
#  2    Total Geral da Despesa por Função
#  3    Total Geral da Despesa por Função
#  4    Total Geral da Despesa por Função
#  ..                                 ...
#  457  Total Geral da Despesa por Função
#  458  Total Geral da Despesa por Função
#  459  Total Geral da Despesa por Função
#  460  Total Geral da Despesa por Função
#  461  Total Geral da Despesa por Função
#
#                                        coluna      cod_conta  \
#  0                        Despesas Empenhadas  TotalDespesas
#  1                        Despesas Empenhadas  TotalDespesas
#  2                        Despesas Empenhadas  TotalDespesas
#  3                        Despesas Empenhadas  TotalDespesas
#  4                        Despesas Empenhadas  TotalDespesas
#  ..                                       ...            ...
#  457  Inscrição de Restos a Pagar Processados  TotalDespesas
#  458  Inscrição de Restos a Pagar Processados  TotalDespesas
#  459  Inscrição de Restos a Pagar Processados  TotalDespesas
#  460  Inscrição de Restos a Pagar Processados  TotalDespesas
#  461  Inscrição de Restos a Pagar Processados  TotalDespesas
#
#                                    conta         valor  populacao
#  0    Despesas Exceto Intraorçamentárias  3.253958e+10    7113540
#  1                      01 - Legislativa  1.357343e+09    7113540
#  2             01.031 - Ação Legislativa  6.567596e+08    7113540
#  3             01.032 - Controle Externo  3.535439e+08    7113540
#  4              FU01 - Demais Subfunções  3.470392e+08    7113540
#  ..                                  ...           ...        ...
#  457               27 - Desporto e Lazer  1.651200e+05    7113540
#  458       27.812 - Desporto Comunitário  1.651200e+05    7113540
#  459             28 - Encargos Especiais  7.210180e+04    7113540
#  460  28.846 - Outros Encargos Especiais  7.210180e+04    7113540
#  461         Despesas Intraorçamentárias  6.270006e+04    7113540
#
#  [462 rows x 11 columns]]

# %% [markdown]
# # Tratamento de dados

# %%
# Dicionário de impostos para análise
impostos = {
    # União
    "IR": "1.1.1.3.00.0.0",
    "IPI": "1.1.1.4.01.0.0",
    "IOF": "1.1.1.5.01.0.0",
    "ITR": "1.1.1.2.01.0.0",
    "Imposto de Importação": "1.1.1.1.01.0.0",
    "Imposto de Exportação": "1.1.1.1.02.0.0",
    # Estados
    "ICMS": "1.1.1.8.02.0.0",
    "IPVA": "1.1.1.8.01.2.0",
    "ITCD": "1.1.1.8.01.3.0"
}

# %%
# Filtra impostos e totaliza arrecadação
dados_q1 = (
    pd.concat(dados_brutos_q1)
    .query(
        "conta.str.contains('|'.join(@impostos.values())) and coluna == 'Receitas Brutas Realizadas' and not (conta.str.contains('1.1.1.3.00.0.0') and uf != 'BR')"
        )
    .assign(
        imposto = lambda x: (
            x.conta
            .replace(
                to_replace = impostos.values(),
                value = impostos.keys(),
                regex = True
                )
            .str.extract("(" + '|'.join(impostos.keys()) + ")")
            ),
        ente = lambda x: np.where(x.uf == "BR", "União", "Estados"),
        valor = lambda x: x.valor / 1e9
        )
    .groupby(by = ["imposto", "ente"], as_index = False)["valor"].sum()
    .pivot(index = "imposto", columns = "ente", values = "valor")
)
dados_q1
# Out:
# ente                      Estados       União
# imposto
# ICMS                   661.126071         NaN
# IOF                           NaN   48.634742
# IPI                           NaN   74.791336
# IPVA                    52.393712         NaN
# IR                            NaN  561.063197
# ITCD                    12.658884         NaN
# ITR                           NaN    2.283819
# Imposto de Exportação         NaN    0.005912
# Imposto de Importação         NaN   62.078663

# %%
# Filtrar funções, totalizar despesas e calcular percentuais
dados_q2 = (
    pd.concat(dados_brutos_q2)
    .query("conta.str.contains('^\\d{2} - ', regex = True) and coluna == 'Despesas Empenhadas'")
    .assign(
        conta = lambda x: x.conta.str.replace(pat = "^\\d{2} - ", repl = "", regex = True),
        ente = lambda x: np.where(x.uf == "BR", "uniao", "estado")
        )
    .groupby(by = ["ente", "conta"], as_index = False)["valor"].sum()
    .pivot(index = "conta", columns = "ente", values = "valor")
    .assign(
        total = lambda x: x.estado.fillna(0) + x.uniao.fillna(0),
        Estados = lambda x: x.estado / x.total,
        **{"União": lambda x: x.uniao / x.total}
        )
    .filter(items = ["Estados", "União"], axis = "columns")
)
dados_q2
# Out:
# <unknown>:1: SyntaxWarning: invalid escape sequence '\d'
#                         Estados     União
# conta
# Administração          0.598445  0.401555
# Agricultura            0.287874  0.712126
# Assistência Social     0.051066  0.948934
# Ciência e Tecnologia   0.426017  0.573983
# Comunicações           0.364069  0.635931
# Comércio e Serviços    0.652711  0.347289
# Cultura                0.731410  0.268590
# Defesa Nacional             NaN  1.000000
# Desporto e Lazer       0.615836  0.384164
# Direitos da Cidadania  0.933675  0.066325
# Educação               0.580908  0.419092
# Encargos Especiais     0.073720  0.926280
# Energia                0.110850  0.889150
# Essencial à Justiça    0.773104  0.226896
# Gestão Ambiental       0.580297  0.419703
# Habitação              0.977258  0.022742
# Indústria              0.307614  0.692386
# Judiciária             0.584741  0.415259
# Legislativa            0.741313  0.258687
# Organização Agrária    0.225788  0.774212
# Previdência Social     0.184195  0.815805
# Relações Exteriores    0.000147  0.999853
# Saneamento             0.909962  0.090038
# Saúde                  0.429325  0.570675
# Segurança Pública      0.884859  0.115141
# Trabalho               0.016892  0.983108
# Transporte             0.794164  0.205836
# Urbanismo              0.359618  0.640382

# %% [markdown]
# # Visualização de dados

# %%
# Gerar gráfico de coluna - Questão 1
dados_q1.sort_values(["Estados", "União"]).plot.barh(stacked = True, title = "Arrecadação de impostos no Brasil - 2021")
# Out:
# <Axes: title={'center': 'Arrecadação de impostos no Brasil - 2021'}, ylabel='imposto'>

# %%
# Gerar gráfico de coluna - Questão 2
dados_q2.sort_values('conta').plot.barh(stacked = True, figsize = (20, 7))
# Out:
# <Axes: ylabel='conta'>
