# %% [markdown]
# <a href="https://colab.research.google.com/github/andersonmoraix/analisedeconjuntura_anotacoes/blob/main/aula02_analiseedecompisicaodoPIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bibliotecas

# %%
# Instala bibliotecas no ambiente pelo pip
# !pip install sidrapy
# Atenção! a biblioteca zetables tem apresentado problemas, portanto, não é recomendodado o seu uso.
# !pip install zentables

# Importa módulos/bibliotecas
import sidrapy as sidra
import pandas as pd
# import zentables as zen
# Out:
# Requirement already satisfied: sidrapy in /usr/local/lib/python3.12/dist-packages (0.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from sidrapy) (2.32.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from sidrapy) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas->sidrapy) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->sidrapy) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->sidrapy) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->sidrapy) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->sidrapy) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->sidrapy) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->sidrapy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->sidrapy) (2025.10.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->sidrapy) (1.17.0)

# %% [markdown]
# # Dados

# %%
# Coleta de dados
dados_brutos = list(
    map(
        # função com 2 argumentos que será repetida
        lambda tabela, variavel: ( # lambda argumento1, argumento2: função/expressão a ser executada
            sidra.get_table(
                table_code = tabela,
                territorial_level = "1", # alguns argumentos recebem valores padrão
                ibge_territorial_code = "all",
                variable = variavel,
                classifications = { # PIB preços mercado e componentes (óticas)
                    "11255": "90687,90691,90696,90707,93404,93405,93406,93407,93408"
                    },
                period = "all"
                )
            ),

        # códigos das tabelas (pro argumento tabela)
        ["1620", "1621", "1846", "6612", "6613"],

        # códigos da variável dentro da tabela (pro argumento variavel)
        ["583", "584", "585", "9318", "9319"]
        )
    )
dados_brutos # lista de DataFrames
# Out:
# [                              NC                 NN  \
#  0     Nível Territorial (Código)  Nível Territorial
#  1                              1             Brasil
#  2                              1             Brasil
#  3                              1             Brasil
#  4                              1             Brasil
#  ...                          ...                ...
#  1058                           1             Brasil
#  1059                           1             Brasil
#  1060                           1             Brasil
#  1061                           1             Brasil
#  1062                           1             Brasil
#
#                                MC                 MN       V              D1C  \
#  0     Unidade de Medida (Código)  Unidade de Medida   Valor  Brasil (Código)
#  1                             30      Número-índice  105.32                1
#  2                             30      Número-índice   93.19                1
#  3                             30      Número-índice   98.31                1
#  4                             30      Número-índice   96.84                1
#  ...                          ...                ...     ...              ...
#  1058                          30      Número-índice  203.34                1
#  1059                          30      Número-índice  161.06                1
#  1060                          30      Número-índice  179.12                1
#  1061                          30      Número-índice  400.94                1
#  1062                          30      Número-índice  307.07                1
#
#           D1N                 D2C                D2N                D3C  \
#  0     Brasil  Trimestre (Código)          Trimestre  Variável (Código)
#  1     Brasil              199601  1º trimestre 1996                583
#  2     Brasil              199601  1º trimestre 1996                583
#  3     Brasil              199601  1º trimestre 1996                583
#  4     Brasil              199601  1º trimestre 1996                583
#  ...      ...                 ...                ...                ...
#  1058  Brasil              202502  2º trimestre 2025                583
#  1059  Brasil              202502  2º trimestre 2025                583
#  1060  Brasil              202502  2º trimestre 2025                583
#  1061  Brasil              202502  2º trimestre 2025                583
#  1062  Brasil              202502  2º trimestre 2025                583
#
#                                                      D3N  \
#  0                                              Variável
#  1     Série encadeada do índice de volume trimestral...
#  2     Série encadeada do índice de volume trimestral...
#  3     Série encadeada do índice de volume trimestral...
#  4     Série encadeada do índice de volume trimestral...
#  ...                                                 ...
#  1058  Série encadeada do índice de volume trimestral...
#  1059  Série encadeada do índice de volume trimestral...
#  1060  Série encadeada do índice de volume trimestral...
#  1061  Série encadeada do índice de volume trimestral...
#  1062  Série encadeada do índice de volume trimestral...
#
#                                  D4C  \
#  0     Setores e subsetores (Código)
#  1                             90687
#  2                             90691
#  3                             90696
#  4                             90707
#  ...                             ...
#  1058                          93404
#  1059                          93405
#  1060                          93406
#  1061                          93407
#  1062                          93408
#
#                                                D4N
#  0                            Setores e subsetores
#  1                            Agropecuária - total
#  2                               Indústria - total
#  3                                Serviços - total
#  4                         PIB a preços de mercado
#  ...                                           ...
#  1058              Despesa de consumo das famílias
#  1059  Despesa de consumo da administração pública
#  1060               Formação bruta de capital fixo
#  1061                Exportação de bens e serviços
#  1062            Importação de bens e serviços (-)
#
#  [1063 rows x 13 columns],
#                                NC                 NN  \
#  0     Nível Territorial (Código)  Nível Territorial
#  1                              1             Brasil
#  2                              1             Brasil
#  3                              1             Brasil
#  4                              1             Brasil
#  ...                          ...                ...
#  1058                           1             Brasil
#  1059                           1             Brasil
#  1060                           1             Brasil
#  1061                           1             Brasil
#  1062                           1             Brasil
#
#                                MC                 MN       V              D1C  \
#  0     Unidade de Medida (Código)  Unidade de Medida   Valor  Brasil (Código)
#  1                             30      Número-índice   95.26                1
#  2                             30      Número-índice   99.87                1
#  3                             30      Número-índice  102.00                1
#  4                             30      Número-índice   99.40                1
#  ...                          ...                ...     ...              ...
#  1058                          30      Número-índice  206.95                1
#  1059                          30      Número-índice  160.42                1
#  1060                          30      Número-índice  181.85                1
#  1061                          30      Número-índice  381.62                1
#  1062                          30      Número-índice  312.29                1
#
#           D1N                 D2C                D2N                D3C  \
#  0     Brasil  Trimestre (Código)          Trimestre  Variável (Código)
#  1     Brasil              199601  1º trimestre 1996                584
#  2     Brasil              199601  1º trimestre 1996                584
#  3     Brasil              199601  1º trimestre 1996                584
#  4     Brasil              199601  1º trimestre 1996                584
#  ...      ...                 ...                ...                ...
#  1058  Brasil              202502  2º trimestre 2025                584
#  1059  Brasil              202502  2º trimestre 2025                584
#  1060  Brasil              202502  2º trimestre 2025                584
#  1061  Brasil              202502  2º trimestre 2025                584
#  1062  Brasil              202502  2º trimestre 2025                584
#
#                                                      D3N  \
#  0                                              Variável
#  1     Série encadeada do índice de volume trimestral...
#  2     Série encadeada do índice de volume trimestral...
#  3     Série encadeada do índice de volume trimestral...
#  4     Série encadeada do índice de volume trimestral...
#  ...                                                 ...
#  1058  Série encadeada do índice de volume trimestral...
#  1059  Série encadeada do índice de volume trimestral...
#  1060  Série encadeada do índice de volume trimestral...
#  1061  Série encadeada do índice de volume trimestral...
#  1062  Série encadeada do índice de volume trimestral...
#
#                                  D4C  \
#  0     Setores e subsetores (Código)
#  1                             90687
#  2                             90691
#  3                             90696
#  4                             90707
#  ...                             ...
#  1058                          93404
#  1059                          93405
#  1060                          93406
#  1061                          93407
#  1062                          93408
#
#                                                D4N
#  0                            Setores e subsetores
#  1                            Agropecuária - total
#  2                               Indústria - total
#  3                                Serviços - total
#  4                         PIB a preços de mercado
#  ...                                           ...
#  1058              Despesa de consumo das famílias
#  1059  Despesa de consumo da administração pública
#  1060               Formação bruta de capital fixo
#  1061                Exportação de bens e serviços
#  1062            Importação de bens e serviços (-)
#
#  [1063 rows x 13 columns],
#                                NC                 NN  \
#  0     Nível Territorial (Código)  Nível Territorial
#  1                              1             Brasil
#  2                              1             Brasil
#  3                              1             Brasil
#  4                              1             Brasil
#  ...                          ...                ...
#  1058                           1             Brasil
#  1059                           1             Brasil
#  1060                           1             Brasil
#  1061                           1             Brasil
#  1062                           1             Brasil
#
#                                MC                 MN        V              D1C  \
#  0     Unidade de Medida (Código)  Unidade de Medida    Valor  Brasil (Código)
#  1                           1550   Milhões de Reais    10054                1
#  2                           1550   Milhões de Reais    41474                1
#  3                           1550   Milhões de Reais   112836                1
#  4                           1550   Milhões de Reais   189323                1
#  ...                          ...                ...      ...              ...
#  1058                        1550   Milhões de Reais  1981934                1
#  1059                        1550   Milhões de Reais   583903                1
#  1060                        1550   Milhões de Reais   532922                1
#  1061                        1550   Milhões de Reais   581343                1
#  1062                        1550   Milhões de Reais   552676                1
#
#           D1N                 D2C                D2N                D3C  \
#  0     Brasil  Trimestre (Código)          Trimestre  Variável (Código)
#  1     Brasil              199601  1º trimestre 1996                585
#  2     Brasil              199601  1º trimestre 1996                585
#  3     Brasil              199601  1º trimestre 1996                585
#  4     Brasil              199601  1º trimestre 1996                585
#  ...      ...                 ...                ...                ...
#  1058  Brasil              202502  2º trimestre 2025                585
#  1059  Brasil              202502  2º trimestre 2025                585
#  1060  Brasil              202502  2º trimestre 2025                585
#  1061  Brasil              202502  2º trimestre 2025                585
#  1062  Brasil              202502  2º trimestre 2025                585
#
#                               D3N                            D4C  \
#  0                       Variável  Setores e subsetores (Código)
#  1     Valores a preços correntes                          90687
#  2     Valores a preços correntes                          90691
#  3     Valores a preços correntes                          90696
#  4     Valores a preços correntes                          90707
#  ...                          ...                            ...
#  1058  Valores a preços correntes                          93404
#  1059  Valores a preços correntes                          93405
#  1060  Valores a preços correntes                          93406
#  1061  Valores a preços correntes                          93407
#  1062  Valores a preços correntes                          93408
#
#                                                D4N
#  0                            Setores e subsetores
#  1                            Agropecuária - total
#  2                               Indústria - total
#  3                                Serviços - total
#  4                         PIB a preços de mercado
#  ...                                           ...
#  1058              Despesa de consumo das famílias
#  1059  Despesa de consumo da administração pública
#  1060               Formação bruta de capital fixo
#  1061                Exportação de bens e serviços
#  1062            Importação de bens e serviços (-)
#
#  [1063 rows x 13 columns],
#                                NC                 NN  \
#  0     Nível Territorial (Código)  Nível Territorial
#  1                              1             Brasil
#  2                              1             Brasil
#  3                              1             Brasil
#  4                              1             Brasil
#  ...                          ...                ...
#  1058                           1             Brasil
#  1059                           1             Brasil
#  1060                           1             Brasil
#  1061                           1             Brasil
#  1062                           1             Brasil
#
#                                MC                 MN          V  \
#  0     Unidade de Medida (Código)  Unidade de Medida      Valor
#  1                           1550   Milhões de Reais    9316.40
#  2                           1550   Milhões de Reais   38456.73
#  3                           1550   Milhões de Reais  100853.26
#  4                           1550   Milhões de Reais  170920.00
#  ...                          ...                ...        ...
#  1058                        1550   Milhões de Reais  228638.81
#  1059                        1550   Milhões de Reais   59493.03
#  1060                        1550   Milhões de Reais   64131.97
#  1061                        1550   Milhões de Reais   53277.52
#  1062                        1550   Milhões de Reais   51247.41
#
#                    D1C     D1N                 D2C                D2N  \
#  0     Brasil (Código)  Brasil  Trimestre (Código)          Trimestre
#  1                   1  Brasil              199601  1º trimestre 1996
#  2                   1  Brasil              199601  1º trimestre 1996
#  3                   1  Brasil              199601  1º trimestre 1996
#  4                   1  Brasil              199601  1º trimestre 1996
#  ...               ...     ...                 ...                ...
#  1058                1  Brasil              202502  2º trimestre 2025
#  1059                1  Brasil              202502  2º trimestre 2025
#  1060                1  Brasil              202502  2º trimestre 2025
#  1061                1  Brasil              202502  2º trimestre 2025
#  1062                1  Brasil              202502  2º trimestre 2025
#
#                      D3C                                  D3N  \
#  0     Variável (Código)                             Variável
#  1                  9318  Valores encadeados a preços de 1995
#  2                  9318  Valores encadeados a preços de 1995
#  3                  9318  Valores encadeados a preços de 1995
#  4                  9318  Valores encadeados a preços de 1995
#  ...                 ...                                  ...
#  1058               9318  Valores encadeados a preços de 1995
#  1059               9318  Valores encadeados a preços de 1995
#  1060               9318  Valores encadeados a preços de 1995
#  1061               9318  Valores encadeados a preços de 1995
#  1062               9318  Valores encadeados a preços de 1995
#
#                                  D4C  \
#  0     Setores e subsetores (Código)
#  1                             90687
#  2                             90691
#  3                             90696
#  4                             90707
#  ...                             ...
#  1058                          93404
#  1059                          93405
#  1060                          93406
#  1061                          93407
#  1062                          93408
#
#                                                D4N
#  0                            Setores e subsetores
#  1                            Agropecuária - total
#  2                               Indústria - total
#  3                                Serviços - total
#  4                         PIB a preços de mercado
#  ...                                           ...
#  1058              Despesa de consumo das famílias
#  1059  Despesa de consumo da administração pública
#  1060               Formação bruta de capital fixo
#  1061                Exportação de bens e serviços
#  1062            Importação de bens e serviços (-)
#
#  [1063 rows x 13 columns],
#                                NC                 NN  \
#  0     Nível Territorial (Código)  Nível Territorial
#  1                              1             Brasil
#  2                              1             Brasil
#  3                              1             Brasil
#  4                              1             Brasil
#  ...                          ...                ...
#  1058                           1             Brasil
#  1059                           1             Brasil
#  1060                           1             Brasil
#  1061                           1             Brasil
#  1062                           1             Brasil
#
#                                MC                 MN          V  \
#  0     Unidade de Medida (Código)  Unidade de Medida      Valor
#  1                           1550   Milhões de Reais    8425.79
#  2                           1550   Milhões de Reais   41213.54
#  3                           1550   Milhões de Reais  104630.26
#  4                           1550   Milhões de Reais  175432.29
#  ...                          ...                ...        ...
#  1058                        1550   Milhões de Reais  232700.31
#  1059                        1550   Milhões de Reais   59255.79
#  1060                        1550   Milhões de Reais   65110.10
#  1061                        1550   Milhões de Reais   50711.34
#  1062                        1550   Milhões de Reais   52118.40
#
#                    D1C     D1N                 D2C                D2N  \
#  0     Brasil (Código)  Brasil  Trimestre (Código)          Trimestre
#  1                   1  Brasil              199601  1º trimestre 1996
#  2                   1  Brasil              199601  1º trimestre 1996
#  3                   1  Brasil              199601  1º trimestre 1996
#  4                   1  Brasil              199601  1º trimestre 1996
#  ...               ...     ...                 ...                ...
#  1058                1  Brasil              202502  2º trimestre 2025
#  1059                1  Brasil              202502  2º trimestre 2025
#  1060                1  Brasil              202502  2º trimestre 2025
#  1061                1  Brasil              202502  2º trimestre 2025
#  1062                1  Brasil              202502  2º trimestre 2025
#
#                      D3C                                                D3N  \
#  0     Variável (Código)                                           Variável
#  1                  9319  Valores encadeados a preços de 1995 com ajuste...
#  2                  9319  Valores encadeados a preços de 1995 com ajuste...
#  3                  9319  Valores encadeados a preços de 1995 com ajuste...
#  4                  9319  Valores encadeados a preços de 1995 com ajuste...
#  ...                 ...                                                ...
#  1058               9319  Valores encadeados a preços de 1995 com ajuste...
#  1059               9319  Valores encadeados a preços de 1995 com ajuste...
#  1060               9319  Valores encadeados a preços de 1995 com ajuste...
#  1061               9319  Valores encadeados a preços de 1995 com ajuste...
#  1062               9319  Valores encadeados a preços de 1995 com ajuste...
#
#                                  D4C  \
#  0     Setores e subsetores (Código)
#  1                             90687
#  2                             90691
#  3                             90696
#  4                             90707
#  ...                             ...
#  1058                          93404
#  1059                          93405
#  1060                          93406
#  1061                          93407
#  1062                          93408
#
#                                                D4N
#  0                            Setores e subsetores
#  1                            Agropecuária - total
#  2                               Indústria - total
#  3                                Serviços - total
#  4                         PIB a preços de mercado
#  ...                                           ...
#  1058              Despesa de consumo das famílias
#  1059  Despesa de consumo da administração pública
#  1060               Formação bruta de capital fixo
#  1061                Exportação de bens e serviços
#  1062            Importação de bens e serviços (-)
#
#  [1063 rows x 13 columns]]

# %%
# Tratamento de dados
dados = (
    pd.concat(  # empilha em uma tabela todos os DataFrames
        objs = dados_brutos,
        keys = ["num_indice", "num_indice_sa", "precos_correntes",
                "precos_constantes", "precos_constantes_sa"],
        names = ["tabela", "linha"]
        )
    .reset_index()
    .rename(columns = dados_brutos[0].iloc[0])
    # filtra na coluna Trimestre tudo que não for igual a "Trimestre" (cabeçalho)
    .query("Trimestre not in 'Trimestre'")
    .rename(
        columns = {
            "Trimestre (Código)": "data",
            "Setores e subsetores": "rubrica",
            "Valor": "valor"
            }
            )
    .filter(items = ["tabela", "data", "rubrica", "valor"], axis = "columns")
    .replace( # recodifica valores da coluna rubrica
        to_replace = {
            "rubrica": {
                "Agropecuária - total": "Agropecuária",
                "Indústria - total": "Indústria",
                "Serviços - total": "Serviços",
                "PIB a preços de mercado": "PIB",
                "Despesa de consumo das famílias": "Consumo das Famílias",
                "Despesa de consumo da administração pública": "Despesa do Governo",
                "Formação bruta de capital fixo": "FBFC",
                "Exportação de bens e serviços": "Exportação",
                "Importação de bens e serviços (-)": "Importação"
                }
                }
             )
    .assign(  # substitui o 5º caracter da coluna data por "-Q" e converte em YYYY-MM-DD
        data = lambda x: pd.to_datetime(
            x.data.str.slice_replace(start = 4, stop = 5, repl = "-Q")
            ),
        valor = lambda x: x.valor.astype(float) # converte de texto para numérico
        )
    )
dados
# Out:
# /tmp/ipython-input-3442246815.py:37: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = lambda x: pd.to_datetime(
#                     tabela       data               rubrica      valor
# 1               num_indice 1996-01-01          Agropecuária     105.32
# 2               num_indice 1996-01-01             Indústria      93.19
# 3               num_indice 1996-01-01              Serviços      98.31
# 4               num_indice 1996-01-01                   PIB      96.84
# 5               num_indice 1996-01-01  Consumo das Famílias      96.06
# ...                    ...        ...                   ...        ...
# 5310  precos_constantes_sa 2025-04-01  Consumo das Famílias  232700.31
# 5311  precos_constantes_sa 2025-04-01    Despesa do Governo   59255.79
# 5312  precos_constantes_sa 2025-04-01                  FBFC   65110.10
# 5313  precos_constantes_sa 2025-04-01            Exportação   50711.34
# 5314  precos_constantes_sa 2025-04-01            Importação   52118.40
#
# [5310 rows x 4 columns]

# %% [markdown]
# # Taxas de Variação

# %%
# Calculando taxas de variação com as fórmulas expostas
taxas = (
    dados.query("tabela in ['num_indice', 'num_indice_sa']") #seleciona a tabela
    .pivot(index = ["data", "rubrica"], columns = "tabela", values = "valor")
    .reset_index()
    .sort_values("data") # ordena ascedentemente pela coluna data
    )
# cria novas colunas/cálculo por grupo (rubrica) feito dentro do apply()
taxas["var_margem"] = (
    taxas.groupby("rubrica", group_keys=False)["num_indice_sa"] # agrupa os dados e aponta a coluna
    .apply(lambda x: x.pct_change(1) * 100)   # calcula a variação na coluna
)
taxas["var_interanual"] = (
    taxas.groupby("rubrica", group_keys=False)["num_indice"]
    .apply(lambda x: x.pct_change(4) * 100)
)
taxas["var_anual"] = (
    taxas.groupby("rubrica", group_keys=False)["num_indice"] # soma móvel de 4 períodos
    .apply(lambda x: (x.rolling(4).sum() / x.rolling(4).sum().shift(4) - 1) * 100)
)
taxas["ano"] = taxas["data"].dt.year
taxas["num_indice_acum"] = (
    taxas.groupby(["rubrica", "ano"], group_keys=False)["num_indice"]
    .apply(lambda x: x.cumsum()) # acumula o número índice por ano/rubrica
    )
taxas["var_acum_ano"] = (
    taxas.groupby("rubrica", group_keys=False)["num_indice_acum"]
    .apply(lambda x: x.pct_change(4) * 100)
)
taxas
# Out:
# tabela       data               rubrica  num_indice  num_indice_sa  \
# 0      1996-01-01          Agropecuária      105.32          95.26
# 1      1996-01-01  Consumo das Famílias       96.06          98.87
# 2      1996-01-01    Despesa do Governo       96.12          99.17
# 3      1996-01-01            Exportação       95.16          99.62
# 4      1996-01-01                  FBFC       92.91          96.84
# ...           ...                   ...         ...            ...
# 1056   2025-04-01            Exportação      400.94         381.62
# 1057   2025-04-01                  FBFC      179.12         181.85
# 1058   2025-04-01            Importação      307.07         312.29
# 1059   2025-04-01             Indústria      144.40         145.07
# 1061   2025-04-01              Serviços      201.63         203.39
#
# tabela  var_margem  var_interanual  var_anual   ano  num_indice_acum  \
# 0              NaN             NaN        NaN  1996           105.32
# 1              NaN             NaN        NaN  1996            96.06
# 2              NaN             NaN        NaN  1996            96.12
# 3              NaN             NaN        NaN  1996            95.16
# 4              NaN             NaN        NaN  1996            92.91
# ...            ...             ...        ...   ...              ...
# 1056      0.707236        1.994403   1.182750  2025           751.40
# 1057     -2.183852        4.139535   8.345622  2025           360.83
# 1058     -2.855632        4.353293  12.818558  2025           615.50
# 1059      0.498788        1.063830   2.386732  2025           282.18
# 1061      0.628340        1.972387   2.897425  2025           398.36
#
# tabela  var_acum_ano
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 1056        1.613318
# 1057        6.599900
# 1058        8.993997
# 1059        1.712144
# 1061        2.031094
#
# [1062 rows x 10 columns]

# %% [markdown]
# # Visualização de dados

# %%
# Gráficos de linha do PIB
(
    taxas.query("rubrica == 'PIB'")
    .filter(
        items = ["data", "var_margem", "var_interanual", "var_anual", "var_acum_ano"],
        axis = "columns"
        )
    .rename(columns = {
        "var_margem": "Var. % margem",
        "var_interanual": "Var. % interanual",
         "var_anual": "Var. % anual",
         "var_acum_ano": "Var. % acumulada no ano"
         }
         )
    .set_index("data") # torna a coluna como índice da tabela
    .plot(             # cria o gráfico com as definições abaixo
        xlabel = "",
        ylabel = "",
        subplots = True,
        layout = (2, 2),
        figsize = (20, 10),
        sharex = False,
        grid = True,
        title = "PIB: taxas de variação\nDados: IBGE | Elaboração: analisemacro.com.br"
        )
    )
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
# Tabela dos componentes do PIB (óticas)
taxas_final = (
    taxas.query("data == data.max()")
    .filter(
        items = ["rubrica", "var_margem", "var_interanual", "var_anual", "var_acum_ano"],
        axis = "columns"
        )
    .rename(columns = {
        "var_margem": "Var. % margem",
        "var_interanual": "Var. % interanual",
         "var_anual": "Var. % anual",
         "var_acum_ano": "Var. % acumulada no ano"
         }
         )
    .set_index("rubrica")
    )
taxas_final
# Out:
#                       Var. % margem  Var. % interanual  Var. % anual  \
# rubrica
# PIB                        0.371882           2.216037      3.178114
# Agropecuária              -0.145278          10.054383      5.833144
# Consumo das Famílias       0.461165           1.807440      3.402566
# Despesa do Governo        -0.576387           0.361416      0.991590
# Exportação                 0.707236           1.994403      1.182750
# FBFC                      -2.183852           4.139535      8.345622
# Importação                -2.855632           4.353293     12.818558
# Indústria                  0.498788           1.063830      2.386732
# Serviços                   0.628340           1.972387      2.897425
#
#                       Var. % acumulada no ano
# rubrica
# PIB                                  2.530669
# Agropecuária                        10.115048
# Consumo das Famílias                 2.176826
# Despesa do Governo                   0.742204
# Exportação                           1.613318
# FBFC                                 6.599900
# Importação                           8.993997
# Indústria                            1.712144
# Serviços                             2.031094

# %%
# taxas_final.zen.pretty(font_size = 12).format(precision = 2)

# %% [markdown]
# # Deflator do PIB

# %%
# Calculando o deflator
deflator = (
    dados.query(
        "tabela in ['precos_correntes', 'precos_constantes'] and rubrica == 'PIB'"
        )
    .pivot(
        index = "data",
        columns = "tabela",
        values = "valor"
        )
    .assign(
        deflator = lambda x: x.precos_correntes / x.precos_constantes * 100,
        var_anual = lambda x: (
            x.deflator.rolling(4).sum() / x.deflator.shift(4).rolling(4).sum() - 1
            ) * 100
        )
    )
deflator
# Out:
# tabela      precos_constantes  precos_correntes    deflator  var_anual
# data
# 1996-01-01          170920.00          189323.0  110.767026        NaN
# 1996-04-01          176708.75          204611.0  115.789965        NaN
# 1996-07-01          189844.26          221513.0  116.681431        NaN
# 1996-10-01          184112.94          239316.0  129.983259        NaN
# 1997-01-01          176732.25          219117.0  123.982465        NaN
# ...                       ...               ...         ...        ...
# 2024-04-01          336102.42         2921229.0  869.148458   4.412729
# 2024-07-01          344057.15         2989913.0  869.016383   4.343849
# 2024-10-01          334488.12         3080367.0  920.919703   3.789329
# 2025-01-01          336495.43         3019579.0  897.361073   4.440068
# 2025-04-01          343551.83         3176745.0  924.677071   5.127370
#
# [118 rows x 4 columns]

# %%
# Gráfico de linha da variação anual do deflator
deflator.var_anual.plot()
# Out:
# <Axes: xlabel='data'>

# %% [markdown]
# # Carrego Estatístico

# %%
# Decomposição do PIB: carrego e crescimento no ano
decomposicao = (
    dados.query("rubrica == 'PIB' and tabela == 'precos_constantes_sa'")
    .assign(
        A = lambda x: x.valor.rolling(4).mean().shift(4),
        B = lambda x: x.valor.shift(4),
        C = lambda x: x.valor.rolling(4).mean(),
        carrego = lambda x: (x.B - x.A) / x.A * 100,
        cres_ano = lambda x: (x.C - x.B) / x.A * 100,
        total = lambda x: x.carrego + x.cres_ano
        )
    .query("data.dt.quarter == 4")
    .assign(ano = lambda x: x.data.dt.year)
    .filter(items = ["ano", "carrego", "cres_ano", "total"])
    .rename(columns = {
        "carrego": "Carrego Estatístico",
        "cres_ano": "Crescimento no Ano",
        "total": "Crescimento Anual"
        }
        )
    )
decomposicao
# Out:
#        ano  Carrego Estatístico  Crescimento no Ano  Crescimento Anual
# 4283  1996                  NaN                 NaN                NaN
# 4319  1997             1.456641            2.267120           3.723762
# 4355  1998             1.450083           -1.093365           0.356718
# 4391  1999            -0.391834            0.860155           0.468322
# 4427  2000             1.190268            3.107388           4.297656
# 4463  2001             1.853806           -0.358876           1.494930
# 4499  2002            -0.660656            3.684659           3.024003
# 4535  2003             1.454573           -0.285168           1.169405
# 4571  2004             0.987824            4.443185           5.431009
# 4607  2005             1.893531            1.738052           3.631583
# 4643  2006             0.980255            2.965595           3.945850
# 4679  2007             1.845485            4.092243           5.937728
# 4715  2008             2.046474            2.740175           4.786649
# 4751  2009            -1.596370            1.766678           0.170308
# 4787  2010             3.502391            4.049632           7.552023
# 4823  2011             1.807248            2.297035           4.104284
# 4859  2012             0.851539            0.760503           1.612042
# 4895  2013             1.373098            1.825151           3.198249
# 4931  2014             0.722477           -0.206652           0.515825
# 4967  2015            -0.044620           -3.495296          -3.539917
# 5003  2016            -2.073812           -1.406086          -3.479898
# 5039  2017            -0.261811            1.886141           1.624330
# 5075  2018             0.792877            0.874722           1.667599
# 5111  2019             0.303725            0.911506           1.215231
# 5147  2020             0.753310           -4.316535          -3.563225
# 5183  2021             4.208852            0.893952           5.102805
# 5219  2022             0.788354            2.338487           3.126841
# 5255  2023             1.111274            2.126351           3.237626
# 5291  2024             0.491876            2.462007           2.953883

# %%
# Visualiza a decomposição do PIB (colunas+linha)
grafico = decomposicao[["ano", "Crescimento Anual"]].plot( # gráfico de linha
    x = "ano",
    linestyle = "dashed",
    marker = "o",
    color = {"Crescimento Anual": "black"},
    use_index = False
    )
grafico = decomposicao[["ano", "Carrego Estatístico", "Crescimento no Ano"]].plot( # coluna
    x = "ano",
    kind = "bar",
    stacked = True,
    ax = grafico, # "adiciona" os dois em um mesmo gráfico
    width = 0.9,
    figsize = (20, 10),
    color = {"Carrego Estatístico": "#b22200", "Crescimento no Ano": "#282f6b"},
    ylabel = "%",
    xlabel = "",
    title = "Decomposição do PIB\nContribuição ao crescimento anual\nDados:" +
    " IBGE | Elaboração: analisemacro.com.br"
    )
grafico.axhline(y = 0, color = "black") # linha horizontal
